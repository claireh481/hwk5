# %%
# Import packages

library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
final.hcris.v2010<-read_csv('../../hwk4/data/output/HCRIS_Data_v2010.csv', show_col_types = FALSE)

# %%
glimpse(final.hcris.v2010)
# Out:
# Rows: 57,802
# Columns: 48
# $ report                       <dbl> 235, 268, 298, 522, 700, 959, 1001, 1091,…
# $ provider_number              <chr> "492007", "044017", "193070", "191311", "…
# $ npi                          <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ fy_start                     <chr> "06/01/2010", "07/01/2010", "07/01/2010",…
# $ fy_end                       <chr> "05/31/2011", "06/30/2011", "06/30/2011",…
# $ date_processed               <chr> "05/22/2012", "05/22/2012", "05/24/2012",…
# $ date_created                 <chr> "05/21/2012", "05/22/2012", "05/22/2012",…
# $ status                       <dbl> 2, 1, 1, 1, 1, 2, 1, 2, 2, 2, 5, 1, 1, 1,…
# $ year                         <dbl> 2010, 2010, 2010, 2010, 2010, 2010, 2010,…
# $ data_source                  <chr> "v2010", "v2010", "v2010", "v2010", "v201…
# $ beds                         <dbl> 35, 16, 15, 25, 25, 125, 417, 62, 33, 17,…
# ...

# %%
medicaid.data <- read_csv('../data/medicaid-exp-data2.csv', show_col_types = FALSE)

# %%
head(medicaid.data)
# Out:
#   State Status of Medicaid Expansion Decision Expansion Year
# 1 AL    Not Adopted                           N/A
# 2 AK    Adopted                               2015
# 3 AZ    Adopted                               2014
# 4 AR    Adopted                               2014
# 5 CA    Adopted                               2014
# 6 CO    Adopted                               2014

# %%
head(final.hcris.v2010)
# Out:
#   report provider_number npi fy_start   fy_end     date_processed date_created
# 1 235    492007          NA  06/01/2010 05/31/2011 05/22/2012     05/21/2012
# 2 268    044017          NA  07/01/2010 06/30/2011 05/22/2012     05/22/2012
# 3 298    193070          NA  07/01/2010 06/30/2011 05/24/2012     05/22/2012
# 4 522    191311          NA  07/01/2010 06/30/2011 05/25/2012     05/25/2012
# 5 700    341311          NA  07/01/2010 06/30/2011 06/08/2012     06/07/2012
# 6 959    072006          NA  07/01/2010 06/30/2011 06/14/2012     06/13/2012
#   status year data_source ⋯ depr_land depr_bldg depr_lease depr_fixed_equip
# 1 2      2010 v2010       ⋯ NA              NA  -26113     -4914
# 2 1      2010 v2010       ⋯ NA        -1339280      NA        NA
# 3 1      2010 v2010       ⋯ NA              NA      NA        NA
# 4 1      2010 v2010       ⋯ NA              NA      NA        NA
# 5 1      2010 v2010       ⋯ NA        -7935442      NA        NA
# ...

# %%
glimpse(medicaid.data)
# Out:
# Rows: 51
# Columns: 3
# $ State                                   <chr> "AL", "AK", "AZ", "AR", "CA", …
# $ `Status of Medicaid Expansion Decision` <chr> "Not Adopted", "Adopted", "Ado…
# $ `Expansion Year`                        <chr> "N/A", "2015", "2014", "2014",…

# %%
# Merge data 

merged_data <- final.hcris.v2010 %>%
  left_join(medicaid.data, by = "state")

merged_data <- merged_data %>%
  mutate(exp_year = as.numeric(exp_year))
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `exp_year = as.numeric(exp_year)`.
# Caused by warning:
# ! NAs introduced by coercion”

# %%
summary(merged_data$medicaid_exp_status)
# Out:
#    Length     Class      Mode
#     57802 character character

# %%
glimpse(merged_data)
# Out:
# Rows: 57,802
# Columns: 50
# $ report                       <dbl> 235, 268, 298, 522, 700, 959, 1001, 1091,…
# $ provider_number              <chr> "492007", "044017", "193070", "191311", "…
# $ npi                          <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N…
# $ fy_start                     <chr> "06/01/2010", "07/01/2010", "07/01/2010",…
# $ fy_end                       <chr> "05/31/2011", "06/30/2011", "06/30/2011",…
# $ date_processed               <chr> "05/22/2012", "05/22/2012", "05/24/2012",…
# $ date_created                 <chr> "05/21/2012", "05/22/2012", "05/22/2012",…
# $ status                       <dbl> 2, 1, 1, 1, 1, 2, 1, 2, 2, 2, 5, 1, 1, 1,…
# $ year                         <dbl> 2010, 2010, 2010, 2010, 2010, 2010, 2010,…
# $ data_source                  <chr> "v2010", "v2010", "v2010", "v2010", "v201…
# $ beds                         <dbl> 35, 16, 15, 25, 25, 125, 417, 62, 33, 17,…
# ...

# %%
write_csv(merged_data, "../data/output/final_exp_data.csv")
